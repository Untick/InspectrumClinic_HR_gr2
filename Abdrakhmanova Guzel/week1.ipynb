# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/InspectrumClinic_HR_gr2/blob/Abdrakhmanova-Guzel-folder/Abdrakhmanova%20Guzel/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Исследование датасета**
#
# 1) Датасет небольшой по размеру (579 анкет). Предполагаю, что его нужно будет расширять и дополнять.
#
# 2) Сам датасет скачивается файлом в формате xlsx. Так как с ним еще работают и он будет корректироваться, то предлагаю разместить его на гугл доках. Уровень доступа там можно корректировать.
#
# 3) Данные в датасете не структурированы и в некоторых случаях заполнены с явными ошибками:
# - колонка "Дата отклика" есть даты 03.03.223 и 12.23.23
# - колонка "ЗП" содержит суммы в разной валюте (рубли, USD, EUR, KZT, KGS, ...)
# - на 8 вакансий всего 11 подходящих анкет (причем эти анкеты только для 4 вакансий)
# - какие требования по 8 вакансиям непонятно
# - колонку "Город" разделить на колонки с городом/страной и колонкой/ами по готовности к командировкам и командировкам
# - у части анкет нет ответа в колонке "Подходит - да/нет"
# - в таблице нет колонок "Ключевые навыки", "Обо мне" (в ТЗ они упоминаются)
#
# 4) Необходимы критерии по всем 8 вакансиям

# %% [markdown]
# **Загрузка таблицы**

# %% [markdown]
# Загрузила файл "dataset.csv" вручную, сама

# %%
import pandas as pd

# %%
import chardet

enc = chardet.detect(open("dataset.csv", 'rb').read())

print(enc)
# Out:
# {'encoding': 'windows-1251', 'confidence': 0.9428428356777072, 'language': 'Russian'}

# %%
data = pd.read_csv("dataset.csv", encoding="windows-1251", sep=";")
data.drop("Unnamed: 0", axis=1, inplace=True)
data.head()
# Out:
#   Дата отклика                              ФИО  \
# 0   23.02.2023                 Bessonova Mariya
# 1   11.01.2023  Ефремова Екатерина Вячеславовна
# 2   27.02.2023          Фролов Артур Михайлович
# 3   11.01.2023         Хозаев Расул Шагаманович
# 4   11.01.2023           Шадрин Олег Михайлович
#
#                                 Пол; возраст            ЗП  \
# 0                                    Женщина   90 000 руб.
# 1                                    Женщина    не указана
# 2  Мужчина, 33 года, родился 23 августа 1989  150 000 руб.
# 3   Мужчина, 32 года, родился 7 декабря 1990    не указана
# 4   Мужчина, 26 лет, родился 21 февраля 1996  150 000 руб.
#
#   Ищет работу на должность                                              Город  \
# 0   Growth Product Manager  Индонезия, Не готова к переезду, не готова к к...
# 1   Growth Product Manager  Москва, Готова к переезду, готова к командировкам
# 2   Growth Product Manager  Санкт-Петербург, Готов к переезду: Москва, гот...
# ...

# %% [markdown]
# **Корреляция таблицы**

# %%
data2 = data.copy()
data2.drop("Дата отклика", axis=1, inplace=True)
data2.drop("Обновление резюме", axis=1, inplace=True)

data2.head()
# Out:
#                                ФИО                               Пол; возраст  \
# 0                 Bessonova Mariya                                    Женщина
# 1  Ефремова Екатерина Вячеславовна                                    Женщина
# 2          Фролов Артур Михайлович  Мужчина, 33 года, родился 23 августа 1989
# 3         Хозаев Расул Шагаманович   Мужчина, 32 года, родился 7 декабря 1990
# 4           Шадрин Олег Михайлович   Мужчина, 26 лет, родился 21 февраля 1996
#
#              ЗП Ищет работу на должность  \
# 0   90 000 руб.   Growth Product Manager
# 1    не указана   Growth Product Manager
# 2  150 000 руб.   Growth Product Manager
# 3    не указана   Growth Product Manager
# 4  150 000 руб.   Growth Product Manager
#
#                                                Город  \
# 0  Индонезия, Не готова к переезду, не готова к к...
# 1  Москва, Готова к переезду, готова к командировкам
# 2  Санкт-Петербург, Готов к переезду: Москва, гот...
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604 entries, 0 to 603
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ФИО                              579 non-null    object
#  1   Пол; возраст                     579 non-null    object
#  2   ЗП                               579 non-null    object
#  3   Ищет работу на должность         579 non-null    object
#  4   Город                            579 non-null    object
#  5   Занятость                        579 non-null    object
#  6   График                           579 non-null    object
#  7   Опыт ()                          579 non-null    object
#  8   Последнее/нынешное место работы  579 non-null    object
#  9   Последняя/нынешняя должность     579 non-null    object
#  10  Образование и ВУЗ                579 non-null    object
#  11  Подходит - да/нет                500 non-null    object
# ...

# %%
data2.corr()
# Out:
# <ipython-input-17-41dc7ecd48ee>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2.corr()
# Empty DataFrame
# Columns: []
# Index: []

# %%
corr = data2.corr(numeric_only=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-3dcb203756ad> in <cell line: 1>()
# ----> 1 corr = data2.corr(numeric_only=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10305         cols = data.columns
#   10306         idx = cols.copy()
# > 10307         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10308
#   10309         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1841         if dtype is not None:
#    1842             dtype = np.dtype(dtype)
# -> 1843         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1844         if result.dtype is not dtype:
#    1845             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %% [markdown]
# Этим методом не получится, так как в таблице нет цифр, только тексты. Нужно стандартизировать таблицу. По каждому стобцу как я понимаю необходимо пройтись и поставить свои значения.
# Мне еще изучить как работать с текстом. Пока это вообще не понимаю. Предполагаю, что наподобие этого: пол мужской 0, пол женский 1

# %% [markdown]
# **Построение модели первой точности**

# %% [markdown]
# Прежде чем строить нужно с таблицей работу закончить.

# %%
# Out:
# <style type="text/css">
# </style>
# <table id="T_521a5" class="dataframe">
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
