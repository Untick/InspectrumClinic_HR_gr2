# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/InspectrumClinic_HR_gr2/blob/Kovaleva-Evgenia-folder/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Работа с массивами данных
import numpy as np 

# Работа с табличными данными
import pandas as pd

# Загрузка датасетов из облака google
import gdown

# Загрузка файла из облака в colab
resume = "https://storage.yandexcloud.net/terratraineeship/23_InspectrumClinic_HR/datasets/%D0%94%D0%B0%D1%82%D0%B0%D0%A1%D0%B5%D1%82%20%D0%9E%D1%86%D0%B5%D0%BD%D0%BA%D0%B0%20%D1%80%D0%B5%D0%B7%D1%8E%D0%BC%D0%B5%20581%20%D1%80%D0%B5%D0%B7%D1%8E%D0%BC%D0%B5.xlsx"
gdown.download(resume, None, quiet=True)
df = pd.read_excel(resume)
display(df)
# Out:
#      Unnamed: 0         Дата отклика                              ФИО  \
# 0             0  2023-02-23 00:00:00                 Bessonova Mariya
# 1             1  2023-01-11 00:00:00  Ефремова Екатерина Вячеславовна
# 2             2  2023-02-27 00:00:00          Фролов Артур Михайлович
# 3             3  2023-01-11 00:00:00         Хозаев Расул Шагаманович
# 4             4  2023-01-11 00:00:00           Шадрин Олег Михайлович
# ..          ...                  ...                              ...
# 574         577  2023-02-28 00:00:00        Логинов Николай Сергеевич
# 575         578  2023-02-17 00:00:00   Шапошников Артём Александрович
# 576         579  2023-02-12 00:00:00             Якупов Айрат Юлаевич
# 577         580  2023-01-24 00:00:00          Петрова Лилия Авгатовна
# 578         581  2023-02-03 00:00:00          Фионина Диана Ралифовна
#
#                                   Пол, возраст            ЗП  \
# 0                                      Женщина   90 000 руб.
# ...
